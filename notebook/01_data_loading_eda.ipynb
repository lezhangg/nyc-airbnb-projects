# %% [markdown]
# # NYC Airbnb Instant Book Experiment: Data Loading and EDA
#
# This notebook loads the Inside Airbnb NYC listings and calendar
# data, cleans it, and then explores the key variables before setting up
# the experiment in Notebook 2.
#
# 1. Load raw listings and calendar data
# 2. Explore both datasets
# 3. Clean and handle missing values
# 4. Check key distributions and baseline occupancy
# 5. Run a power analysis to determine sample size needed
# 6. Export the cleaned dataset for Notebook 2

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil

pd.set_option('future.no_silent_downcasting', True)
sns.set_theme(style='whitegrid', palette='muted')

# %% [markdown]
# ## Load Data
# ### Data source: [Inside Airbnb](http://insideairbnb.com/get-the-data)
# ### — New York City, May 2025 snapshot.

# %%
path = "data/"

listings = pd.read_csv(path + "listings.csv.gz", compression='gzip', low_memory=False)
calendar = pd.read_csv(path + "calendar.csv.gz", compression='gzip', low_memory=False)

print(f'Listings : {listings.shape}')
print(f'Calendar : {calendar.shape}')
# Out:
# Listings : (37018, 79)
# Calendar : (13499675, 7)

# %% [markdown]
# ## Exploratory Data Analysis: Calendar

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13499675 entries, 0 to 13499674
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 721.0+ MB

# %%
calendar.head(9)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0        2539  2025-05-02         f  $299.00            NaN            30.0
# 1        2539  2025-05-03         f  $299.00            NaN            30.0
# 2        2539  2025-05-04         f  $299.00            NaN            30.0
# 3        2539  2025-05-05         f  $299.00            NaN            30.0
# 4        2539  2025-05-06         f  $299.00            NaN            30.0
# 5        2539  2025-05-07         f  $299.00            NaN            30.0
# 6        2539  2025-05-08         f  $299.00            NaN            30.0
# 7        2539  2025-05-09         f  $299.00            NaN            30.0
# 8        2539  2025-05-10         f  $299.00            NaN            30.0
#
#    maximum_nights
# 0           730.0
# 1           730.0
# 2           730.0
# 3           730.0
# 4           730.0
# 5           730.0
# 6           730.0
# 7           730.0
# 8           730.0

# %%
calendar.describe()
# Out:
#          listing_id  minimum_nights  maximum_nights
# count  1.349968e+07    1.349599e+07    1.349599e+07
# mean   4.372466e+17    3.024958e+01    8.155863e+05
# std    5.143709e+17    4.157294e+01    4.181157e+07
# min    2.539000e+03    1.000000e+00    1.000000e+00
# 25%    2.138494e+07    3.000000e+01    3.650000e+02
# 50%    5.037663e+07    3.000000e+01    7.000000e+02
# 75%    9.257247e+17    3.000000e+01    1.125000e+03
# max    1.410916e+18    1.250000e+03    2.147484e+09

# %%
# Null percentages per column in calendar sorted from highest to lowest 
calendar_null_percent= (calendar.isnull().sum()/len(calendar)*100).round(2)
print(calendar_null_percent.sort_values(ascending = False).to_string())
# Out:
# adjusted_price    99.99
# minimum_nights     0.03
# maximum_nights     0.03
# listing_id         0.00
# date               0.00
# available          0.00
# price              0.00

# %% [markdown]
# # Exploratory Data Analysis: Listings

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37018 entries, 0 to 37017
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            37018 non-null  int64
#  1   listing_url                                   37018 non-null  object
#  2   scrape_id                                     37018 non-null  int64
#  3   last_scraped                                  37018 non-null  object
#  4   source                                        37018 non-null  object
#  5   name                                          37016 non-null  object
#  6   description                                   36011 non-null  object
#  7   neighborhood_overview                         19575 non-null  object
#  8   picture_url                                   37017 non-null  object
#  9   host_id                                       37018 non-null  int64
#  10  host_url                                      37018 non-null  object
#  11  host_name                                     36993 non-null  object
#  12  host_since                                    36993 non-null  object
#  13  host_location                                 29481 non-null  object
#  14  host_about                                    21385 non-null  object
#  15  host_response_time                            21625 non-null  object
#  16  host_response_rate                            21625 non-null  object
#  17  host_acceptance_rate                          22373 non-null  object
#  18  host_is_superhost                             36613 non-null  object
#  19  host_thumbnail_url                            36993 non-null  object
#  20  host_picture_url                              36993 non-null  object
#  21  host_neighbourhood                            29669 non-null  object
#  22  host_listings_count                           36993 non-null  float64
#  23  host_total_listings_count                     36993 non-null  float64
#  24  host_verifications                            36993 non-null  object
#  25  host_has_profile_pic                          36993 non-null  object
#  26  host_identity_verified                        36993 non-null  object
#  27  neighbourhood                                 19576 non-null  object
#  28  neighbourhood_cleansed                        37018 non-null  object
#  29  neighbourhood_group_cleansed                  37018 non-null  object
#  30  latitude                                      37018 non-null  float64
#  31  longitude                                     37018 non-null  float64
#  32  property_type                                 37018 non-null  object
#  33  room_type                                     37018 non-null  object
#  34  accommodates                                  37018 non-null  int64
#  35  bathrooms                                     22047 non-null  float64
#  36  bathrooms_text                                36983 non-null  object
#  37  bedrooms                                      30846 non-null  float64
#  38  beds                                          21923 non-null  float64
#  39  amenities                                     37018 non-null  object
#  40  price                                         21833 non-null  object
#  41  minimum_nights                                37018 non-null  int64
#  42  maximum_nights                                37018 non-null  int64
#  43  minimum_minimum_nights                        36993 non-null  float64
#  44  maximum_minimum_nights                        36993 non-null  float64
#  45  minimum_maximum_nights                        36993 non-null  float64
#  46  maximum_maximum_nights                        36993 non-null  float64
#  47  minimum_nights_avg_ntm                        36993 non-null  float64
#  48  maximum_nights_avg_ntm                        36993 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              31381 non-null  object
#  51  availability_30                               37018 non-null  int64
#  52  availability_60                               37018 non-null  int64
#  53  availability_90                               37018 non-null  int64
#  54  availability_365                              37018 non-null  int64
#  55  calendar_last_scraped                         37018 non-null  object
#  56  number_of_reviews                             37018 non-null  int64
#  57  number_of_reviews_ltm                         37018 non-null  int64
#  58  number_of_reviews_l30d                        37018 non-null  int64
#  59  availability_eoy                              37018 non-null  int64
#  60  number_of_reviews_ly                          37018 non-null  int64
#  61  estimated_occupancy_l365d                     37018 non-null  int64
#  62  estimated_revenue_l365d                       21833 non-null  float64
#  63  first_review                                  25358 non-null  object
#  64  last_review                                   25358 non-null  object
#  65  review_scores_rating                          25358 non-null  float64
#  66  review_scores_accuracy                        25348 non-null  float64
#  67  review_scores_cleanliness                     25357 non-null  float64
#  68  review_scores_checkin                         25344 non-null  float64
#  69  review_scores_communication                   25352 non-null  float64
#  70  review_scores_location                        25341 non-null  float64
#  71  review_scores_value                           25342 non-null  float64
#  72  license                                       5396 non-null   object
#  73  instant_bookable                              37018 non-null  object
#  74  calculated_host_listings_count                37018 non-null  int64
#  75  calculated_host_listings_count_entire_homes   37018 non-null  int64
#  76  calculated_host_listings_count_private_rooms  37018 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   37018 non-null  int64
#  78  reviews_per_month                             25358 non-null  float64
# dtypes: float64(23), int64(20), object(36)
# memory usage: 22.3+ MB

# %%
listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2539  https://www.airbnb.com/rooms/2539  20250501160219   2025-05-02
# 1  2595  https://www.airbnb.com/rooms/2595  20250501160219   2025-05-02
# 2  5136  https://www.airbnb.com/rooms/5136  20250501160219   2025-05-02
# 3  6848  https://www.airbnb.com/rooms/6848  20250501160219   2025-05-01
# 4  6872  https://www.airbnb.com/rooms/6872  20250501160219   2025-05-01
#
#             source                                               name  \
# 0  previous scrape   Superfast Wi-Fi.  Clean & quiet home by the park
# 1      city scrape           Skylit Midtown Manhattan Spacious Studio
# 2      city scrape    Spacious Family Friendly Duplex w/ Patio + Yard
# 3      city scrape                   Only 2 stops to Manhattan studio
# 4      city scrape  Uptown Sanctuary w/ Private Bath (Month to Month)
#
#                                          description  \
# 0  Renovated apartment home in an elevator buildi...
# 1  Beautiful, spacious skylit studio in the heart...
# 2  We welcome you to stay in our lovely 2 br, 130...
# 3  Comfortable studio apartment with super comfor...
# 4  This charming distancing-friendly month-to-mon...
#
#                                neighborhood_overview  \
# 0    Close to Prospect Park and Historic Ditmas Park
# 1  Centrally located in the heart of Manhattan ju...
# 2                                                NaN
# 3                                                NaN
# 4  This sweet Harlem sanctuary is a 10-20 minute ...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/hosting/Hosti...     2787  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...     2845  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     7378  ...
# 3  https://a0.muscache.com/pictures/e4f031a7-f146...    15991  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...    16104  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         5.0                   4.75                4.88
# 1                         4.8                   4.81                4.40
# 2                         5.0                   4.75                4.75
# 3                         4.8                   4.69                4.58
# 4                         5.0                   5.00                5.00
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              5
# 1     NaN                f                              3
# 2     NaN                t                              1
# 3     NaN                f                              1
# 4     NaN                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           3
# 2                                           1
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            4
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.08
# 1                                           0              0.26
# 2                                           0              0.03
# 3                                           0              1.00
# 4                                           0              0.03
#
# [5 rows x 79 columns]

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.701800e+04  3.701800e+04  3.701800e+04         36993.000000
# mean   4.372920e+17  2.025050e+13  1.714205e+08           286.645041
# std    5.144149e+17  0.000000e+00  1.888658e+08          1084.829208
# min    2.539000e+03  2.025050e+13  1.678000e+03             1.000000
# 25%    2.140000e+07  2.025050e+13  1.768211e+07             1.000000
# 50%    5.037505e+07  2.025050e+13  8.655362e+07             2.000000
# 75%    9.261013e+17  2.025050e+13  3.036643e+08            10.000000
# max    1.410916e+18  2.025050e+13  6.919326e+08          5367.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               36993.000000  37018.000000  37018.000000  37018.000000
# mean                  375.088287     40.728570    -73.947247      2.773083
# std                  1299.238924      0.056333      0.055007      1.917539
# min                     1.000000     40.500366    -74.251907      1.000000
# 25%                     1.000000     40.688420    -73.983460      2.000000
# 50%                     3.000000     40.726132    -73.955001      2.000000
# 75%                    15.000000     40.762271    -73.928302      4.000000
# max                  9084.000000     40.912017    -73.711822     16.000000
#
#           bathrooms      bedrooms  ...  review_scores_cleanliness  \
# count  22047.000000  30846.000000  ...               25357.000000
# mean       1.201932      1.385431  ...                   4.661004
# std        0.556949      0.930676  ...                   0.495871
# min        0.000000      0.000000  ...                   0.000000
# 25%        1.000000      1.000000  ...                   4.540000
# 50%        1.000000      1.000000  ...                   4.820000
# 75%        1.000000      2.000000  ...                   5.000000
# max       15.500000     15.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           25344.000000                 25352.000000
# mean                4.836200                     4.826887
# std                 0.372115                     0.408087
# min                 0.000000                     0.000000
# 25%                 4.820000                     4.820000
# 50%                 4.950000                     4.960000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count            25341.000000         25342.000000
# mean                 4.744965             4.644073
# std                  0.390465             0.486165
# min                  0.000000             0.000000
# 25%                  4.660000             4.540000
# 50%                  4.850000             4.765000
# 75%                  5.000000             4.950000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                    37018.000000
# mean                        72.739802
# std                        235.286250
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          8.000000
# max                       1225.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 37018.000000
# mean                                     51.326436
# std                                     221.236309
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                    1225.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  37018.000000
# mean                                      19.406262
# std                                       89.511742
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                      633.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 37018.000000       25358.000000
# mean                                      0.029094           0.819498
# std                                       0.406795           1.851575
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.080000
# 50%                                       0.000000           0.260000
# 75%                                       0.000000           0.940000
# max                                      13.000000         120.430000
#
# [8 rows x 43 columns]

# %%
# Show all listings columns with null percentage — sorted highest to lowest

null_percent = (listings.isnull().sum() / len(listings) * 100).round(2)
print(null_percent.sort_values(ascending=False).to_string())
# Out:
# calendar_updated                                100.00
# license                                          85.42
# neighborhood_overview                            47.12
# neighbourhood                                    47.12
# host_about                                       42.23
# host_response_rate                               41.58
# host_response_time                               41.58
# estimated_revenue_l365d                          41.02
# price                                            41.02
# beds                                             40.78
# bathrooms                                        40.44
# host_acceptance_rate                             39.56
# review_scores_checkin                            31.54
# review_scores_value                              31.54
# review_scores_location                           31.54
# review_scores_accuracy                           31.53
# review_scores_communication                      31.51
# review_scores_cleanliness                        31.50
# review_scores_rating                             31.50
# last_review                                      31.50
# first_review                                     31.50
# reviews_per_month                                31.50
# host_location                                    20.36
# host_neighbourhood                               19.85
# bedrooms                                         16.67
# has_availability                                 15.23
# description                                       2.72
# host_is_superhost                                 1.09
# bathrooms_text                                    0.09
# maximum_nights_avg_ntm                            0.07
# minimum_nights_avg_ntm                            0.07
# maximum_maximum_nights                            0.07
# minimum_maximum_nights                            0.07
# maximum_minimum_nights                            0.07
# minimum_minimum_nights                            0.07
# host_total_listings_count                         0.07
# host_listings_count                               0.07
# host_verifications                                0.07
# host_name                                         0.07
# host_since                                        0.07
# host_thumbnail_url                                0.07
# host_picture_url                                  0.07
# host_identity_verified                            0.07
# host_has_profile_pic                              0.07
# name                                              0.01
# instant_bookable                                  0.00
# number_of_reviews_l30d                            0.00
# availability_eoy                                  0.00
# number_of_reviews_ly                              0.00
# estimated_occupancy_l365d                         0.00
# number_of_reviews                                 0.00
# calculated_host_listings_count_shared_rooms       0.00
# calculated_host_listings_count                    0.00
# calculated_host_listings_count_private_rooms      0.00
# calculated_host_listings_count_entire_homes       0.00
# number_of_reviews_ltm                             0.00
# id                                                0.00
# calendar_last_scraped                             0.00
# availability_365                                  0.00
# scrape_id                                         0.00
# last_scraped                                      0.00
# source                                            0.00
# picture_url                                       0.00
# host_id                                           0.00
# host_url                                          0.00
# neighbourhood_cleansed                            0.00
# neighbourhood_group_cleansed                      0.00
# latitude                                          0.00
# longitude                                         0.00
# property_type                                     0.00
# room_type                                         0.00
# accommodates                                      0.00
# listing_url                                       0.00
# minimum_nights                                    0.00
# maximum_nights                                    0.00
# availability_30                                   0.00
# availability_60                                   0.00
# availability_90                                   0.00
# amenities                                         0.00

# %% [markdown]
# # Data Cleaning

# %%
# Dropped adjusted_price because null percentage close to 100
calendar_clean = calendar[['listing_id','date','available','price','minimum_nights','maximum_nights']].copy()
calendar_clean['available']= calendar_clean['available'].map({'t':True,'f':False})
calendar_clean['date'] = pd.to_datetime(calendar_clean['date'])
# Removed $ in front of price for clarity and easier for models 
calendar_clean['price'] = (calendar_clean['price'].str.replace('[$,]','',regex=True).astype(float))
# Change type from float to int to represent days
calendar_clean['minimum_nights']=calendar_clean['minimum_nights'].astype('Int64')
calendar_clean['maximum_nights']=calendar_clean['maximum_nights'].astype('Int64')

# %%
calendar_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13499675 entries, 0 to 13499674
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            datetime64[ns]
#  2   available       bool
#  3   price           float64
#  4   minimum_nights  Int64
#  5   maximum_nights  Int64
# dtypes: Int64(2), bool(1), datetime64[ns](1), float64(1), int64(1)
# memory usage: 553.6 MB

# %% [markdown]
# ## Cleaned Calendar Table

# %%
calendar_clean.head()
# Out:
#    listing_id       date  available  price  minimum_nights  maximum_nights
# 0        2539 2025-05-02      False  299.0              30             730
# 1        2539 2025-05-03      False  299.0              30             730
# 2        2539 2025-05-04      False  299.0              30             730
# 3        2539 2025-05-05      False  299.0              30             730
# 4        2539 2025-05-06      False  299.0              30             730

# %%
print(f'Shape: {calendar_clean.shape}')
print(f'\nData types:\n{calendar_clean.dtypes}')
print(f'\nNull counts:\n{calendar_clean.isnull().sum()}')
print(f'\nAvailable vs Not available breakdown:\n{calendar_clean["available"].value_counts()}')
print(f'\nDate range: {calendar_clean["date"].min()} to {calendar_clean["date"].max()}')
calendar_clean = calendar_clean.dropna(subset=['minimum_nights', 'maximum_nights'])

print(f'\nUpdated Shape: {calendar_clean.shape}')
# Out:
# Shape: (13499675, 6)
#
# Data types:
# listing_id                 int64
# date              datetime64[ns]
# available                   bool
# price                    float64
# minimum_nights             Int64
# maximum_nights             Int64
# dtype: object
#
# Null counts:
# listing_id           0
# date                 0
# available            0
# price                0
# minimum_nights    3689
# maximum_nights    3689
# dtype: int64
#
# Available vs Not available breakdown:
# available
# False    7778621
# True     5721054
# Name: count, dtype: int64
#
# Date range: 2025-05-01 00:00:00 to 2026-05-05 00:00:00
#
# Updated Shape: (13495986, 6)

# %%
print(listings[['estimated_occupancy_l365d', 'number_of_reviews_ly', 'number_of_reviews_l30d']].corr())
# Out:
#                            estimated_occupancy_l365d  number_of_reviews_ly  \
# estimated_occupancy_l365d                   1.000000              0.430887
# number_of_reviews_ly                        0.430887              1.000000
# number_of_reviews_l30d                      0.399208              0.804818
#
#                            number_of_reviews_l30d
# estimated_occupancy_l365d                0.399208
# number_of_reviews_ly                     0.804818
# number_of_reviews_l30d                   1.000000

# %% [markdown]
#  Host_is_superhost excluded -- largely captured by review_scores_rating
#  and potentially a mediator rather than a true confounder

# %%
listings_clean = listings[[
     # Identifiers
    'id',
    'host_id',

    # Treatment variable
    'instant_bookable',             

    # Propensity score matching variables — need all of these
    'room_type',                    
    'neighbourhood_cleansed',       # Neighborhoods
    'neighbourhood_group_cleansed', # borough 
    'accommodates',                 
    'review_scores_rating',         

    # Primary metric
    'estimated_occupancy_l365d',    

    # Secondary metrics
    'number_of_reviews_ltm',       
    'number_of_reviews',    
     'number_of_reviews_ly',

    # Guardrail metrics
    'price',                       

    # Subgroup analysis
    'property_type',              
    'minimum_nights',               
    'host_is_superhost',            
    'host_identity_verified',      
    'availability_30', 'availability_365',

    # Location
    'latitude',
    'longitude',
]].copy()

print(listings_clean.isnull().sum())
print(f'\nShape: {listings_clean.shape}')
# Out:
# id                                  0
# host_id                             0
# instant_bookable                    0
# room_type                           0
# neighbourhood_cleansed              0
# neighbourhood_group_cleansed        0
# accommodates                        0
# review_scores_rating            11660
# estimated_occupancy_l365d           0
# number_of_reviews_ltm               0
# number_of_reviews                   0
# number_of_reviews_ly                0
# price                           15185
# property_type                       0
# minimum_nights                      0
# host_is_superhost                 405
# host_identity_verified             25
# availability_30                     0
# availability_365                    0
# latitude                            0
# longitude                           0
# dtype: int64
#
# Shape: (37018, 21)

# %%
# Null percentage for listings sorted from highest to lowest 
listings_clean_null_percent = (listings_clean.isnull().sum()/len(listings_clean)*100).round(2)
print(listings_clean_null_percent.sort_values(ascending = False).to_string())
# Out:
# price                           41.02
# review_scores_rating            31.50
# host_is_superhost                1.09
# host_identity_verified           0.07
# id                               0.00
# number_of_reviews_ly             0.00
# latitude                         0.00
# availability_365                 0.00
# availability_30                  0.00
# minimum_nights                   0.00
# property_type                    0.00
# number_of_reviews                0.00
# host_id                          0.00
# number_of_reviews_ltm            0.00
# estimated_occupancy_l365d        0.00
# accommodates                     0.00
# neighbourhood_group_cleansed     0.00
# neighbourhood_cleansed           0.00
# room_type                        0.00
# instant_bookable                 0.00
# longitude                        0.00

# %%
listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37018 entries, 0 to 37017
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            37018 non-null  int64
#  1   host_id                       37018 non-null  int64
#  2   instant_bookable              37018 non-null  object
#  3   room_type                     37018 non-null  object
#  4   neighbourhood_cleansed        37018 non-null  object
#  5   neighbourhood_group_cleansed  37018 non-null  object
#  6   accommodates                  37018 non-null  int64
#  7   review_scores_rating          25358 non-null  float64
#  8   estimated_occupancy_l365d     37018 non-null  int64
#  9   number_of_reviews_ltm         37018 non-null  int64
#  10  number_of_reviews             37018 non-null  int64
#  11  number_of_reviews_ly          37018 non-null  int64
#  12  price                         21833 non-null  object
#  13  property_type                 37018 non-null  object
#  14  minimum_nights                37018 non-null  int64
#  15  host_is_superhost             36613 non-null  object
#  16  host_identity_verified        36993 non-null  object
#  17  availability_30               37018 non-null  int64
#  18  availability_365              37018 non-null  int64
#  19  latitude                      37018 non-null  float64
#  20  longitude                     37018 non-null  float64
# dtypes: float64(3), int64(10), object(8)
# memory usage: 5.9+ MB

# %%
# Cleaning list
listings_clean['instant_bookable'] = listings_clean['instant_bookable'].map({'t':True, 'f':False})
listings_clean['host_is_superhost'] = listings_clean['host_is_superhost'].map({'t':True, 'f':False})
listings_clean['host_identity_verified'] = listings_clean['host_identity_verified'].map({'t':True,'f':False})
listings_clean['host_identity_verified'] = listings_clean['host_identity_verified'].fillna(False)

if listings_clean['price'].dtype == object:
    listings_clean['price'] = listings_clean['price'].str.replace('[$,]', '', regex=True).astype(float)

# %% [markdown]
# ### Handling missing values
#
# - **Review_scores_rating (31.5% null):** No reviews yet, not missing
#   data. Filled with 0, flagged with `has_reviews`. Checked this doesn't
#   bias the treatment/control comparison — unrated listings are balanced
#   between groups (34.6% vs 35.5%). Note: Project 2 uses median instead,
#   since distance-based methods there are sensitive to 0 as an outlier.
# - **Price (41% null):** Filled with median price by room type — entire
#   homes and private rooms have different price distributions.
# - **Host_is_superhost (1.09% null):** Dropped — status unknown, can't
#   assign to subgroups.

# %%
# 3. Handling nulls
listings_clean['has_reviews'] = listings_clean['review_scores_rating'].notna()  # ← flag BEFORE filling
listings_clean['review_scores_rating'] = listings_clean['review_scores_rating'].fillna(0)
listings_clean['price'] = listings_clean.groupby('room_type')['price'].transform(
    lambda x: x.fillna(x.median())
)
listings_clean = listings_clean.dropna(subset=['host_is_superhost'])

listings_clean['host_is_superhost'] = listings_clean['host_is_superhost'].astype(bool)

# %%
print(f'Shape: {listings_clean.shape}')
print(f'\nData_types:\n{listings_clean.dtypes}')
print(f'\nRemaining nulls:\n{listings_clean.isnull().sum()[listings_clean.isnull().sum() > 0]}')
print(f'\nInstant bookable:\n{listings_clean["instant_bookable"].value_counts()}')
print(f'\nSuperhost:\n{listings_clean["host_is_superhost"].value_counts()}')
# Out:
# Shape: (36613, 22)
#
# Data_types:
# id                                int64
# host_id                           int64
# instant_bookable                   bool
# room_type                        object
# neighbourhood_cleansed           object
# neighbourhood_group_cleansed     object
# accommodates                      int64
# review_scores_rating            float64
# estimated_occupancy_l365d         int64
# number_of_reviews_ltm             int64
# number_of_reviews                 int64
# number_of_reviews_ly              int64
# price                           float64
# property_type                    object
# minimum_nights                    int64
# host_is_superhost                  bool
# host_identity_verified           object
# availability_30                   int64
# availability_365                  int64
# latitude                        float64
# longitude                       float64
# has_reviews                        bool
# dtype: object
#
# Remaining nulls:
# Series([], dtype: int64)
#
# Instant bookable:
# instant_bookable
# False    29108
# True      7505
# Name: count, dtype: int64
#
# Superhost:
# host_is_superhost
# False    30014
# True      6599
# Name: count, dtype: int64

# %%
print(listings_clean['host_is_superhost'].unique())
print(listings_clean['host_is_superhost'].dtype)
print(listings_clean['host_is_superhost'].value_counts(dropna=False))
# Out:
# [False  True]
# bool
# host_is_superhost
# False    30014
# True      6599
# Name: count, dtype: int64

# %% [markdown]
# ## Cleaned Listings Table

# %%
listings_clean.head(10)
# Out:
#      id  host_id  instant_bookable        room_type neighbourhood_cleansed  \
# 0  2539     2787             False     Private room             Kensington
# 1  2595     2845             False  Entire home/apt                Midtown
# 2  5136     7378              True  Entire home/apt            Sunset Park
# 3  6848    15991             False  Entire home/apt           Williamsburg
# 4  6872    16104             False     Private room            East Harlem
# 5  6990    16800             False     Private room            East Harlem
# 6  7064    17297             False     Private room           Williamsburg
# 7  7097    17571              True     Private room            Fort Greene
# 8  7801    21207             False  Entire home/apt           Williamsburg
# 9  8490    25183             False  Entire home/apt     Bedford-Stuyvesant
#
#   neighbourhood_group_cleansed  accommodates  review_scores_rating  \
# 0                     Brooklyn             2                  4.89
# 1                    Manhattan             1                  4.68
# 2                     Brooklyn             4                  4.75
# 3                     Brooklyn             3                  4.58
# 4                    Manhattan             1                  5.00
# 5                    Manhattan             1                  4.88
# 6                     Brooklyn             2                  4.91
# 7                     Brooklyn             2                  4.89
# 8                     Brooklyn             2                  4.91
# 9                     Brooklyn             5                  4.77
#
#    estimated_occupancy_l365d  number_of_reviews_ltm  ...  price  \
# 0                          0                      0  ...   85.0
# 1                          0                      0  ...  240.0
# 2                          0                      0  ...  216.0
# 3                        240                      4  ...   96.0
# 4                          0                      0  ...   59.0
# 5                        255                      5  ...   59.0
# 6                          0                      0  ...   85.0
# 7                        255                     37  ...  195.0
# 8                         60                      1  ...  290.0
# 9                          0                      0  ...  170.0
#
#                  property_type  minimum_nights host_is_superhost  \
# 0        Private room in condo              30             False
# 1           Entire rental unit              30             False
# 2           Entire rental unit              30             False
# 3           Entire rental unit              30              True
# 4        Private room in condo              30             False
# 5  Private room in rental unit              30             False
# 6         Private room in loft              30             False
# 7  Private room in guest suite               2              True
# 8                 Entire place              30              True
# 9                  Entire loft              30             False
#
#    host_identity_verified  availability_30 availability_365   latitude  \
# 0                    True                8              343  40.645290
# 1                    True               30              365  40.753560
# 2                    True                0               37  40.662650
# 3                    True                5              182  40.709350
# 4                   False               23               83  40.801070
# 5                    True                2              209  40.787780
# 6                    True                0                0  40.712480
# 7                    True                1               29  40.691940
# 8                    True                0                0  40.718807
# 9                    True                3              191  40.684556
#
#    longitude  has_reviews
# 0 -73.972380         True
# 1 -73.985590         True
# 2 -73.994540         True
# 3 -73.953420         True
# 4 -73.942550         True
# 5 -73.947590         True
# 6 -73.958810         True
# 7 -73.973890         True
# 8 -73.956177         True
# 9 -73.939634         True
#
# [10 rows x 22 columns]

# %% [markdown]
# # Key Distributions

# %% [markdown]
# ## Instant Booking Breakdown
# ## Key distributions

# %%
# Checking instant bookable vs request to book
listings_clean['ib_label'] = listings_clean['instant_bookable'].map(
    {True: 'Instant Book', False: 'Request to Book'}
)
# Make sure clean data is ready
print(listings_clean.shape)
print(listings_clean['instant_bookable'].value_counts())
print(listings_clean['ib_label'].value_counts())
print(listings_clean.isnull().sum()[listings_clean.isnull().sum() > 0])
# Out:
# (36613, 23)
# instant_bookable
# False    29108
# True      7505
# Name: count, dtype: int64
# ib_label
# Request to Book    29108
# Instant Book        7505
# Name: count, dtype: int64
# Series([], dtype: int64)

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 15))
fig.suptitle('Airbnb NYC — EDA by Instant Book status', fontsize=14, y=1.02)
# Plot 1 — Instant Book breakdown
sns.countplot(data=listings_clean, x= 'ib_label', hue ='ib_label',
              palette=['steelblue', 'coral'], ax=axes[0,0])
axes[0,0].set_title('Instant Book vs Request to Book')
axes[0,0].set_xlabel('')
axes[0,0].set_ylabel('Number of listings')

 # Plot 2 — Price by Instant Book status
sns.boxplot(data=listings_clean, x='ib_label', y='price', hue='ib_label',
            palette=['steelblue', 'coral'], legend=False, ax=axes[0,1],
            showfliers=False)
axes[0,1].set_title('Price by Instant Book status')
axes[0,1].set_xlabel('')
axes[0,1].set_ylabel('Nightly price ($)')

# Plot 3 — Review scores by Instant Book status
reviewed = listings_clean[listings_clean['has_reviews']]
sns.boxplot(data=reviewed, x='ib_label', y='review_scores_rating', hue='ib_label',
            palette=['steelblue', 'coral'], legend=False, ax=axes[0,2],
            showfliers=False)
axes[0,2].set_title('Review scores by Instant Book status')
axes[0,2].set_xlabel('')
axes[0,2].set_ylabel('Review score')

# Plot 4 — Room type by Instant Book status
sns.countplot(data=listings_clean, x='room_type', hue='ib_label',
              palette=['steelblue', 'coral'], ax=axes[1,0])
axes[1,0].set_title('Room type by Instant Book status')
axes[1,0].set_xlabel('')
axes[1,0].set_ylabel('Number of listings')
axes[1,0].tick_params(axis='x', rotation=15)
axes[1,0].legend(title='', fontsize=9)

# Plot 5 — Occupancy by Instant Book status
sns.boxplot(data=listings_clean, x='ib_label', y='estimated_occupancy_l365d',
            hue='ib_label', palette=['steelblue', 'coral'], legend=False,
            ax=axes[1,1], showfliers=False)
axes[1,1].set_title('Occupancy by Instant Book status ← primary metric')
axes[1,1].set_xlabel('')
axes[1,1].set_ylabel('Estimated occupancy (days/year)')

# Plot 6 — Occupancy distribution overall
sns.histplot(data=listings_clean, x='estimated_occupancy_l365d',
             bins=30, ax=axes[1,2], color='steelblue')
axes[1,2].set_title('Occupancy distribution')
axes[1,2].set_xlabel('Estimated occupancy (days/year)')
axes[1,2].set_ylabel('Number of listings')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## EDA findings
#
# **Plot 1 — Group imbalance between Request to Book vs Instant Book:**
# Instant Book listings represent only 20.5% of all listings (7,505 vs
# 29,108). This 80/20 imbalance means direct comparison would be
# unreliable — motivates propensity score matching in Notebook 2.
#
# **Plot 2 — Price difference:**
# Instant Book listings are more expensive — median nightly price around
# $200 vs $135 for Request to Book, with a much wider spread (whiskers
# extending to $730 vs $380). Higher-priced listings may attract
# different guest behavior independent of the Instant Book feature
# itself.
#
# **Plot 3 — Review score difference:**
# Request to Book listings have higher, more consistent review scores
# (median 4.87, tight IQR from 4.67 to 5.0). Instant Book listings show a
# lower median (4.77) and much wider variance, with scores dropping as
# low as 3.9 — suggesting more variable listing quality.
#
# **Plot 4 — Room type imbalance:**
# Both groups are dominated by entire homes and private rooms, but the
# mix differs — Request to Book skews more heavily toward private rooms
# (13,300 vs 2,900 for Instant Book), while Instant Book has a larger
# relative share of entire homes (4,000 vs 15,700 for Request to Book).
# Hotel and shared rooms are a small fraction of both groups. Different
# room type mixes likely come with systematically different booking
# patterns.
#
# **Plot 5 — Pre-existing occupancy difference:**
# Instant Book listings already show slightly higher median occupancy
# (~64 vs ~60 days/year) before any experiment intervention.
#
# **Plot 6 — Occupancy distribution:**
# Heavily right-skewed, with about 25,500 listings clustered at or near
# 0 days of occupancy — suggesting a floor effect where a large share of
# listings get little to no bookings.
#
# **Overall conclusion:**
# Instant Book and non-Instant Book listings differ systematically on
# price, review scores, room type mix, and baseline occupancy. Direct
# comparison would produce biased results. Propensity score matching on
# these variables (plus accommodates and minimum nights) is required
# before experiment analysis.

# %% [markdown]
# ## Baseline occupancy rate

# %%
# Baseline occupancy rate from estimated_occupancy_l365d
baseline_rate = (listings_clean['estimated_occupancy_l365d'] / 365).mean()
print(f'Baseline occupancy rate: {baseline_rate:.4f} ({baseline_rate:.2%})')

# Split by instant book status
baseline_by_group = (
    listings_clean
    .assign(occupancy_rate=listings_clean['estimated_occupancy_l365d'] / 365)
    .groupby('instant_bookable')['occupancy_rate']
    .mean()
    .reset_index()
)
baseline_by_group['instant_bookable'] = baseline_by_group['instant_bookable'].map(
    {True: 'Instant Book', False: 'Request to Book'}
)
print(f'\nBaseline by group:\n{baseline_by_group}')
# Out:
# Baseline occupancy rate: 0.1279 (12.79%)
#
# Baseline by group:
#   instant_bookable  occupancy_rate
# 0  Request to Book        0.120588
# 1     Instant Book        0.156125

# %% [markdown]
# ### Baseline occupancy rate
#
# Overall baseline came out to 12.79% — this is what I used for
# the power analysis.
#
# Interesting finding here: Request to Book listings actually have
# lower occupancy (12.06%) than Instant Book listings (15.61%). I
# initially expected the opposite based on an earlier
# calculation.
#
# The earlier calculation counted every listing-day in the calendar,
# so groups with more overall bookings ended up pulling the average up
# — and since Request to Book has way more volume, that's what happened
# there. Switching to estimated_occupancy_l365d instead, where each
# listing only counts once, gave Instant Book the higher average —
# which lines up better with the rest of the analysis.

# %% [markdown]
# ## Power Test

# %%
def calculate_sample_size(baseline_rate, mde, alpha=0.05, power=0.80):
    """
    Calculate required sample size per group for a two-proportions z-test.
    
    Formula:
        baseline_rate : control group conversion rate
        mde           : minimum detectable effect (absolute)
        alpha         : significance level (default 0.05)
        power         : statistical power (default 0.80)
    
    Returns:
        n : required sample size per group
    """
    # Treatment rate
    treatment_rate = baseline_rate + mde
    
    # Z scores
    z_alpha = stats.norm.ppf(1 - alpha / 2)  # two-tailed
    z_beta  = stats.norm.ppf(power)
    
    # Variances
    var_control   = baseline_rate * (1 - baseline_rate)
    var_treatment = treatment_rate * (1 - treatment_rate)
    
    # Sample size formula
    n = ((z_alpha + z_beta) ** 2 * (var_control + var_treatment)) / (mde ** 2)
    
    return ceil(n)

# Experiment parameters
BASELINE_RATE = 0.1279
MDE           = 0.02
ALPHA         = 0.05
POWER         = 0.80

n = calculate_sample_size(BASELINE_RATE, MDE, ALPHA, POWER)

print("-" * 45)
print("Power analysis results")
print("-" * 45)
print(f"Baseline conversion rate  : {BASELINE_RATE:.4f} ({BASELINE_RATE:.2%})")
print(f"Treatment rate (expected) : {BASELINE_RATE + MDE:.4f} ({BASELINE_RATE + MDE:.2%})")
print(f"Minimum detectable effect : {MDE:.2%}")
print(f"Significance level (α)    : {ALPHA}")
print(f"Statistical power (1-β)   : {POWER:.0%}")
print(f"Z_alpha                   : {stats.norm.ppf(1 - ALPHA/2):.3f}")
print(f"Z_beta                    : {stats.norm.ppf(POWER):.3f}")
print("-" * 45)
print(f"Required n per group      : {n:,}")
print(f"Total required            : {n*2:,}")
print("-" * 45)

 # Check against available listings
instant_book_count = listings_clean['instant_bookable'].sum()
request_book_count = (~listings_clean['instant_bookable']).sum()

print(f"\nAvailable listings:")
print(f"Instant Book    : {instant_book_count:,}")
print(f"Request to Book : {request_book_count:,}")
print(f"\nHave enough?")
print(f"Instant Book    : {'Yes' if instant_book_count >= n else 'Not enough'}")
print(f"Request to Book : {'Yes' if request_book_count >= n else 'Not enough'}")
# Out:
# ---------------------------------------------
# Power analysis results
# ---------------------------------------------
# Baseline conversion rate  : 0.1279 (12.79%)
# Treatment rate (expected) : 0.1479 (14.79%)
# Minimum detectable effect : 2.00%
# Significance level (α)    : 0.05
# Statistical power (1-β)   : 80%
# Z_alpha                   : 1.960
# Z_beta                    : 0.842
# ---------------------------------------------
# Required n per group      : 4,662
# Total required            : 9,324
# ---------------------------------------------
#
# Available listings:
# Instant Book    : 7,505
# Request to Book : 29,108
#
# Have enough?
# Instant Book    : Yes
# Request to Book : Yes

# %% [markdown]
# ### Power analysis — corrected baseline
#
# I originally calculated the baseline at 57.61% by averaging occupancy
# across every listing-day in the calendar, but that didn't actually
# match the metric I was testing. Once I switched to
# estimated_occupancy_l365d (per-listing average) to match my actual
# outcome variable, the baseline came down to 12.79%.
#
# That lower baseline — further from 50%, where variance is highest —
# meant I needed fewer listings than I originally thought to detect an
# effect. That gave me room to tighten the minimum detectable effect
# from a 20% relative lift down to 16%.
#
# | Parameter | Value |
# |---|---|
# | Baseline occupancy | 12.79% |
# | MDE | 16% relative lift (2.0 points) |
# | Required n per group | 4,662 |
# | Matched pairs available | 6,765 (45% buffer) |
#
# A 16% relative lift works out to roughly 7.3 extra booked days per
# listing per year — a real, meaningful lift, and comfortably detectable
# given how much data I had to work with.

# %% [markdown]
# # Exporting Clean Data

# %%
# export clean datasets
listings_clean.to_csv(path + 'listings_clean.csv', index=False)
calendar_clean.to_csv(path + 'calendar_clean.csv', index=False)

print(f'listings_clean exported: {listings_clean.shape}')
print(f'calendar_clean exported: {calendar_clean.shape}')
# Out:
# listings_clean exported: (36613, 23)
# calendar_clean exported: (13495986, 6)
